# %% [markdown]
# # 🌐 [Lab Name]
#
# <nav style="background-color: #003366; padding: 10px; border-radius: 4px;">
# <a href="#about-the-lab" style="color: white; margin-right: 15px;">About</a>
# <a href="#research-focus" style="color: white; margin-right: 15px;">Research</a>
# <a href="#our-team" style="color: white; margin-right: 15px;">Team</a>
# <a href="#recent-publications" style="color: white; margin-right: 15px;">Publications</a>
# <a href="#contact-us" style="color: white;">Contact</a>
# </nav>
#
# ---
#
# ## 🧪 Atmospheric Informatics (AI)
# *Research Laboratory*
#
# 📍 Center for Computational Sciences, University of Tsukuba
# 📍 Tsukuba City, Japan
# 🔗 [labwebsite.example.com](#)
#
# ---
#
# <a id="about-the-lab"></a>
# ## 🔬 About the Lab
#
# > “Insert a compelling one-liner here.”
#
# We are an interdisciplinary research team focused on **[core topics: e.g., AI-driven weather forecasting, urban climate risk, and regional modeling]**.
# Our mission is to advance fundamental and applied science through innovative methodologies, collaborative approaches, and open knowledge.
#
# ---
#
# <a id="research-focus"></a>
# ## 🧭 Research Focus
#
# | Area                      | Description                                                     |
# |---------------------------|-----------------------------------------------------------------|
# | Urban Climate Modeling   | Understanding city-scale climate variability under global warming. |
# | AI for Weather Prediction| Leveraging machine learning to improve forecasts.                |
# | Heatwave & Risk Assessment | Quantifying impacts and identifying adaptation options.        |
#
# ---
#
# <a id="our-team"></a>
# ## 👥 Our Team
#
# ### 🧑‍🔬 Principal Investigator
# **Dr. [Your Full Name]**
# _Associate Professor, [Department]_
# ✉️ [you@university.edu](mailto:you@university.edu) | 🌐 [yourhomepage.com](#)
#
# ### 👩‍🔬 Lab Members
# - **[Name]** – Postdoc | *Urban Data Science*
# - **[Name]** – PhD Student | *AI + Heatwaves*
# - **[Name]** – RA | *Tool development & visualization*
#
# ---
#
# <a id="recent-publications"></a>
# ## 📚 Recent Publications
#
# <details>
# <summary>Click to expand</summary>
#
# - **Smith et al. (2024)**. *Urban Climate Modeling with Deep Networks*. _Nature Climate Science_
# - **Lee & Doan (2023)**. *Downscaling Heat Extremes Using GANs*. _J. Hydromet._
# - **Doan, Q.-V. (2022)**. *Complex Network Analysis of Heatwaves in Japan*. _ERL_
#
# [View all on Google Scholar](https://scholar.google.com)
#
# </details>
#
# ---
#
# ## 🛠️ Tools & Datasets
#
# We develop and maintain open-source research tools:
#
# - 🔧 **[ToolName](#)** – Python library for [task]
# - 📊 **[DatasetName](#)** – High-resolution climate data for [region]
#
# ---
#
# ## 📰 News & Highlights
#
# - `2025-04-10`: 🎓 We're hiring a new PhD student!
# - `2025-03-15`: 📄 Paper accepted in *Nature Climate Science*
# - `2025-02-01`: 🎤 Presented at AGU Fall Meeting 2025
#
# ---
#
# ## 🤝 Collaborations & Support
#
# ### 🔗 Collaborating Institutions
# - Univ. of Tokyo, Japan
# - NCAR, USA
# - ETH Zurich, Switzerland
#
# ### 💰 Funding Agencies
# - Japan Society for the Promotion of Science (JSPS)
# - JST Moonshot Program
# - [Grant/Award XYZ]
#
# ---
#
# <a id="contact-us"></a>
# ## 📬 Contact Us
#
# **[Lab Name] Research Laboratory**
# Center for Computational Sciences
# University of Tsukuba
# 1-1-1 Tennodai, Tsukuba, Ibaraki, Japan
#
# ✉️ [you@university.ac.jp](mailto:you@university.ac.jp) | 🌐 [labwebsite.com](#) | 🐦 [@LabTwitter](#)

# %%
ls images/
# Out:
# 3D_vapor.jpg                gakui_program_logo.jpg
# Atmos_info.jpg              geosci_logo.jpg
# CCS_logo.jpg                taikibunya_logo.jpg
# TsukubaU_logo.jpg           urbanization_NY_Mexico.jpg
# extreme_clim.jpg

# %% [markdown]
# # 🌐 Atmospheric Informatics Laboratory
# ### Unlocking the Future of Climate Science with AI, Data, and Innovation
#
# ## 🔍 Our Focus Areas
#
# | ![AI & Earth](images/Atmos_info.jpg) | ![Modeling](images/3D_vapor.jpg) | ![Extreme Weather](images/extreme_clim.jpg) | ![Urban Climate](images/urbanization_NY_Mexico.jpg) |
# |:-----------------------------------:|:--------------------------------:|:--------------------------------------------:|:----------------------------------------------------:|
# | **Atmospheric Informatics** <br> Leveraging AI and data mining to uncover novel patterns and dynamics in the atmosphere. | **Numerical Modeling** <br> Advancing weather and climate models, with a focus on land–atmosphere interactions. | **Extreme Weather & Climate** <br> Exploring drivers and dynamics of extreme events in a changing climate. | **Urban Climate** <br> Investigating urbanization and global change impacts, identifying risks and mitigation pathways. |
#
# ## 💡 Why Invest?
#
# - **Cutting-Edge Innovation**: Pioneering the intersection of atmospheric science and artificial intelligence.
# - **Global Relevance**: Delivering insights from local resilience planning to global climate strategies.
# - **Interdisciplinary Strength**: Integrating climate physics, data science, and urban sustainability research.
#
# ---
#
# ### 🔗 Contact Us
#
# 📍 Room 302, Center for Computational Sciences, University of Tsukuba
# 📬 doan.van.gb@u.tsukuba.ac.jp

# %% [markdown]
# <div style="font-size: 1.1em;">
#
# # 🌐 Atmospheric Informatics Laboratory
#
# <p style="text-align: center; font-size: 1.1em; font-style: italic; margin-bottom: 25px; max-width: 80%; margin-left: auto; margin-right: auto;">
#   We are entering a new era of atmospheric science—empowered by tools like artificial intelligence, high-performance computing, and big data analytics. Our mission is to explore how these capabilities are reshaping the way we understand and predict our planet's atmosphere.
# </p>
#
#
# <table style="background-color: #f3f7fa; border-radius: 0px; padding: 10px; font-size: 1.1em;; background-color: #f3f7fa; border: 0px solid #ccc; border-collapse: separate; border-spacing: 10px;">
# <tr>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/Atmos_info.jpg" style="width:400px; margin:-0px 0 0 -30px;">
#     </div>
#     <strong>Atmospheric Informatics</strong><br>
#     Leveraging AI and data mining to uncover novel patterns and dynamics in the atmosphere.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/3D_vapor.jpg" style="width:2000px; margin:-10px 0 0 -20px;">
#     </div>
#     <strong>Numerical Modeling</strong><br>
#     Advancing weather and climate models, with a focus on land–atmosphere interactions.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/extreme_clim.jpg" style="width:400px; margin:-0px 0 0 -25px;">
#     </div>
#     <strong>Extreme Weather & Climate</strong><br>
#     Exploring drivers and dynamics of extreme events in a changing climate.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/urbanization_NY_Mexico.jpg" style="width:400px; margin:-0px 0 0 -5px;">
#     </div>
#     <strong>Urban Climate</strong><br>
#     Investigating urbanization and global change impacts, identifying risks and mitigation pathways.
#   </td>
# </tr>
# </table>
#
#
# ### 🔗 Contact Point
#
# 📍 Room 302, Center for Computational Sciences, University of Tsukuba  <br>
# 📬 doan.van.gb@u.tsukuba.ac.jp
#
# </div>

# %% [markdown]
# <div style="font-size: 1.1em; overflow-x: hidden;">
#
# # 🌐 Atmospheric Informatics Laboratory (AI-Lab)
#
# <p style="text-align: center; font-size: 1.1em; font-style: italic; margin-bottom: 25px; max-width: 80%; margin-left: auto; margin-right: auto;">
#   "In a new era of atmospheric science—empowered by artificial intelligence, high-performance computing, and big data analytics, our mission is to explore how these capabilities are reshaping the way we explain and predict our planet's atmosphere."
# </p>
#
#
# <table style="max-width: 100%; table-layout: fixed; width: 100%; margin: 0 auto; background-color: #f3f7fa; border-radius: 8px; padding: 10px; font-size: 1.1em;; background-color: #f3f7fa; border: 0px solid #ccc; border-collapse: separate; border-spacing: 10px;">
# <tr>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/Atmos_info.jpg" style="width:400px; margin:-0px 0 0 -30px;">
#     </div>
#     <strong>Atmospheric Informatics</strong><br>
#     Leveraging AI and data mining to uncover novel patterns and dynamics in the atmosphere.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/3D_vapor.jpg" style="width:400px; margin:-10px 0 0 -30px;">
#     </div>
#     <strong>Numerical Modeling</strong><br>
#     Advancing weather and climate models, with a focus on land–atmosphere interactions.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/extreme_clim.jpg" style="width:400px; margin:-0px 0 0 -25px;">
#     </div>
#     <strong>Extreme Weather & Climate</strong><br>
#     Exploring drivers and dynamics of extreme events in a changing climate.
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/urbanization_NY_Mexico.jpg" style="width:400px; margin:-0px 0 0 -25px;">
#     </div>
#     <strong>Urban Climate</strong><br>
#     Investigating urbanization and global change impacts, identifying risks and mitigation pathways.
#   </td>
# </tr>
# </table>
#
#
# #### 🔗 Contact Point
#
# 📍 Room 302, Center for Computational Sciences, University of Tsukuba  <br>
# 📬 doan.van.gb@u.tsukuba.ac.jp
#
# </div>

# %% [markdown]
# <div style="font-size: 1.1em; overflow-x: hidden;">
#
# # 🌐 大気情報学研究室（Atmospheric Informatics Laboratory）
#
#
# <table style="max-width: 100%; table-layout: fixed; width: 100%; margin: 0 auto; background-color: #f3f7fa; border-radius: 8px; padding: 10px; font-size: 1.1em;; background-color: #f3f7fa; border: 1px solid #ccc; border-collapse: separate; border-spacing: 10px;">
# <tr>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/Atmos_info.jpg" style="width:400px; margin:-0px 0 0 -30px;">
#     </div>
#     <strong>大気情報学</strong><br>
#     AIやデータマイニングの活用
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/3D_vapor.jpg" style="width:400px; margin:-10px 0 0 -30px;">
#     </div>
#     <strong>数値モデル</strong><br>
#     大気と陸面の相互作用に着目した気候・気象モデルの開発・応用
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/extreme_clim.jpg" style="width:400px; margin:-0px 0 0 -25px;">
#     </div>
#     <strong>極端気象・気候</strong><br>
#     領域気候変動と極端気象・気候
#   </td>
#   <td style="vertical-align: top;">
#     <div style="width:240px; height:160px; overflow:hidden;">
#       <img src="images/urbanization_NY_Mexico.jpg" style="width:400px; margin:-0px 0 0 -25px;">
#     </div>
#     <strong>都市気候</strong><br>
#     都市化と地球温暖化が気候への影響
#   </td>
# </tr>
# </table>
#
#
# ### 🔗 お問い合わせ
#
#
#
#
#
# DOAN Quang Van 准教授
# 📍 計算科学研究センター 302室  <br>
# 📬 doan.van.gb@u.tsukuba.ac.jp
#
# </div>

# %%
from PIL import Image

image_files = [
    "images/Atmos_info.jpg",
    "images/3D_vapor.jpg",
    "images/extreme_clim.jpg",
    "images/urbanization_NY_Mexico.jpg"
]

for img_path in image_files:
    try:
        with Image.open(img_path) as img:
            print(f"{img_path}: {img.size[0]}x{img.size[1]} pixels")
    except FileNotFoundError:
        print(f"{img_path}: ❌ Not found")
# Out:
# images/Atmos_info.jpg: 960x540 pixels
# images/3D_vapor.jpg: 2048x1152 pixels
# images/extreme_clim.jpg: 960x540 pixels
# images/urbanization_NY_Mexico.jpg: 892x333 pixels
